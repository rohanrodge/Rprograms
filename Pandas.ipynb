# %% [markdown]
# <a href="https://colab.research.google.com/github/rohanrodge/Rprograms/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.read_csv('/content/nba.csv')
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df=pd.read_csv('/content/nba.csv')

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
df["Team"]=="Boston Celtics"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Name: Team, Length: 458, dtype: bool

# %%
df[(df['Team']=="Boston Celtics")&(df['Weight']<100.0)]
# Out:
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Height, Weight, College, Salary]
# Index: []
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_0.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# ...

# %%
(df['Team']=="Boston Celtics")&(df['Weight']<100.0)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Length: 458, dtype: bool

# %%
df[df['Team']=="Boston Celtics"]
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2      John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3       R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4     Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5      Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7      Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8      Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9      Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 10  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 11    Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# ...

# %%
(df['Team']=="Boston Celtics") & (df['Weight']<100.0)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Length: 458, dtype: bool

# %%
df[df['Team']=="Los Angeles Lakers"]
# Out:
#                   Name                Team  Number Position   Age Height  \
# 106       Brandon Bass  Los Angeles Lakers     2.0       PF  31.0    6-8
# 107        Tarik Black  Los Angeles Lakers    28.0        C  24.0    6-9
# 108      Anthony Brown  Los Angeles Lakers     3.0       SF  23.0    6-7
# 109        Kobe Bryant  Los Angeles Lakers    24.0       SF  37.0    6-6
# 110    Jordan Clarkson  Los Angeles Lakers     6.0       PG  24.0    6-5
# 111        Roy Hibbert  Los Angeles Lakers    17.0        C  29.0    7-2
# 112    Marcelo Huertas  Los Angeles Lakers     9.0       PG  33.0    6-3
# 113         Ryan Kelly  Los Angeles Lakers     4.0       PF  25.0   6-11
# 114    Larry Nance Jr.  Los Angeles Lakers     7.0       PF  23.0    6-9
# 115      Julius Randle  Los Angeles Lakers    30.0       PF  21.0    6-9
# 116   D'Angelo Russell  Los Angeles Lakers     1.0       PG  20.0    6-5
# 117       Robert Sacre  Los Angeles Lakers    50.0        C  27.0    7-0
# ...

# %%
df[df['Team']=="Los Angeles Lakers"]["Salary"]
# Out:
# 106     3000000.0
# 107      845059.0
# 108      700000.0
# 109    25000000.0
# 110      845059.0
# 111    15592217.0
# 112      525093.0
# 113     1724250.0
# 114     1155600.0
# 115     3132240.0
# 116     5103120.0
# 117      981348.0
# 118     7000000.0
# 119      947276.0
# 120     5219169.0
# Name: Salary, dtype: float64

# %%
df[df['Team']=="Los Angeles Lakers"]["Salary"].mean()
# Out:
# 4784695.4

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df[df['Position']=='PG']['Salary'].mean()
# Out:
# 5077829.215909091

# %%
df[df['Position']=='SF']['Salary'].mean()
# Out:
# 4857392.571428572

# %%
df[df['Position']=='SG']['Salary'].mean()
# Out:
# 4009861.1919191917

# %%
df[df['Position']=='C']['Salary'].mean()
# Out:
# 5967052.0

# %%
df[df["College"]=="San Diego State"]
# Out:
#               Name               Team  Number Position   Age Height  Weight  \
# 301  Kawhi Leonard  San Antonio Spurs     2.0       SF  24.0    6-7   230.0
#
#              College      Salary
# 301  San Diego State  16407500.0

# %%
df.groupby("Position")["Salary"].mean()
# Out:
# Position
# C     5.967052e+06
# PF    4.562483e+06
# PG    5.077829e+06
# SF    4.857393e+06
# SG    4.009861e+06
# Name: Salary, dtype: float64

# %%
df[df['Team']=="Toronto Raptors"]
# Out:
#                  Name             Team  Number Position   Age Height  Weight  \
# 61    Bismack Biyombo  Toronto Raptors     8.0        C  23.0    6-9   245.0
# 62      Bruno Caboclo  Toronto Raptors    20.0       SF  20.0    6-9   205.0
# 63    DeMarre Carroll  Toronto Raptors     5.0       SF  29.0    6-8   212.0
# 64      DeMar DeRozan  Toronto Raptors    10.0       SG  26.0    6-7   220.0
# 65      James Johnson  Toronto Raptors     3.0       PF  29.0    6-9   250.0
# 66        Cory Joseph  Toronto Raptors     6.0       PG  24.0    6-3   190.0
# 67         Kyle Lowry  Toronto Raptors     7.0       PG  30.0    6-0   205.0
# 68     Lucas Nogueira  Toronto Raptors    92.0        C  23.0    7-0   220.0
# 69  Patrick Patterson  Toronto Raptors    54.0       PF  27.0    6-9   235.0
# 70      Norman Powell  Toronto Raptors    24.0       SG  23.0    6-4   215.0
# 71      Terrence Ross  Toronto Raptors    31.0       SF  25.0    6-7   195.0
# ...

# %%
df[df['Team']=="Toronto Raptors"]["Salary"].mean()
# Out:
# 4741174.066666666

# %%
df[df['Team']=="Toronto Raptors"]["Salary"].max()
# Out:
# 13600000.0

# %%
df[df['Team']=="Toronto Raptors"].sort_values("Salary")
# Out:
#                  Name             Team  Number Position   Age Height  Weight  \
# 73     Jason Thompson  Toronto Raptors     1.0       PF  29.0   6-11   250.0
# 70      Norman Powell  Toronto Raptors    24.0       SG  23.0    6-4   215.0
# 75       Delon Wright  Toronto Raptors    55.0       PG  24.0    6-5   190.0
# 62      Bruno Caboclo  Toronto Raptors    20.0       SF  20.0    6-9   205.0
# 68     Lucas Nogueira  Toronto Raptors    92.0        C  23.0    7-0   220.0
# 65      James Johnson  Toronto Raptors     3.0       PF  29.0    6-9   250.0
# 61    Bismack Biyombo  Toronto Raptors     8.0        C  23.0    6-9   245.0
# 72         Luis Scola  Toronto Raptors     4.0       PF  36.0    6-9   240.0
# 71      Terrence Ross  Toronto Raptors    31.0       SF  25.0    6-7   195.0
# 74  Jonas Valanciunas  Toronto Raptors    17.0        C  24.0    7-0   255.0
# 69  Patrick Patterson  Toronto Raptors    54.0       PF  27.0    6-9   235.0
# ...

# %%
df[df['Team']=="Toronto Raptors"].sort_values("Salary",ascending=False)
# Out:
#                  Name             Team  Number Position   Age Height  Weight  \
# 63    DeMarre Carroll  Toronto Raptors     5.0       SF  29.0    6-8   212.0
# 67         Kyle Lowry  Toronto Raptors     7.0       PG  30.0    6-0   205.0
# 64      DeMar DeRozan  Toronto Raptors    10.0       SG  26.0    6-7   220.0
# 66        Cory Joseph  Toronto Raptors     6.0       PG  24.0    6-3   190.0
# 69  Patrick Patterson  Toronto Raptors    54.0       PF  27.0    6-9   235.0
# 74  Jonas Valanciunas  Toronto Raptors    17.0        C  24.0    7-0   255.0
# 71      Terrence Ross  Toronto Raptors    31.0       SF  25.0    6-7   195.0
# 72         Luis Scola  Toronto Raptors     4.0       PF  36.0    6-9   240.0
# 61    Bismack Biyombo  Toronto Raptors     8.0        C  23.0    6-9   245.0
# 65      James Johnson  Toronto Raptors     3.0       PF  29.0    6-9   250.0
# 68     Lucas Nogueira  Toronto Raptors    92.0        C  23.0    7-0   220.0
# ...
